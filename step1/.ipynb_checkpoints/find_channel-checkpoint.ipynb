# %%
import requests 
from bs4 import BeautifulSoup 
  
def news(url): 
    list_ = []
    # the target we want to open     
    
      
    #open with GET method 
    resp=requests.get(url) 
      
    #http_respone 200 means OK status 
    if resp.status_code==200: 
      
        # we need a parser,Python built-in HTML parser is enough . 
        soup=BeautifulSoup(resp.text,'html.parser')     
  
        # l is the list which contains all the text i.e news  
    
        href =soup.findAll("h2",{"class":"c_title"}) 
        for l in href:
            l = str(l)

            st = l[l.find('href')+4:]
            st = st[:st.find('>')]
            id_= ''
            x = st.split('/')
            id_ = x[len(x)-1]
            #print(id_[:id_.find('"')])


            list_.append(id_[:id_.find('"')])
        #now we want to print only the text part of the anchor. 
        #find all the elements of a, i.e anchor 
        #for i in l.findAll("a"): 
        #    print(i.text) 
    else: 
        print("Error")
    return list_

# %%
import numpy as np
categories = ['animals','anime','art-design','architecture','auto-moto','celebrities','education','travel',
           'fashion-beauty','food','feetness','gaming','health','magezine','music','nature','news','photo','sport',
             'science','technology','video','other','economic','religion','cooking','Romantic','movie','shop']
my_ids = []
j = 0
channels ={}
for i in categories:
    url='https://mychannels.ir/soroush/'+i
    ids = news(url)
    print(ids)
    for d in ids:
        channels[d] = [-1,j]
        j+=1
        my_ids.append(d)
# Out:
# ['animalshelter', 'bazar_dam', 'phoenix_ilove', 'natgeo', 'siadpaliz', 'zalooparvar.fadak', 'teyur966', 'Just_Fish', 'poultry96', 'LarrySerra', 'amozeshkadecanary', 'national_geographik', 'aquarium_fish', 'akvaruom.farzad', 'toyyyour']
# ['otaku.net', 'behtarinanime', 'animefun', 'hamidmixer', 'koodakonline1', 'cartoonstv1', 'animation_kotah', 'andeshezeba', 'clip_irancartoon', 'og_instagram', 'clip_kodakane', 'tom_and_jery', 'clip_babsfangi', 'clip_cartoon', 'clip_doniayecartoon']
# ['tarh.graph', 'Tablofarsh.chehre.mandegar', 'logowhiteblack', 'avindordoneh', 'fatjmazahrayas', 'artist_painter', 'Mr.geraphic', 'namadarzan', 'ms_logo.ir', 'Angoshtar_khatam', 'sobhanms', 'parvanjf', 'epoxsiii', 'naziricalligraphy', 'Kaghzqom']
# ['kayerpipe', '3dmax_farsi', 'cc.architect', 'mojriha', 'decokara', 'urbanity', 'MAXWORLD_IR', 'decoraat', 'ostadekargari']
# ['WAcars', '1dande_ir', 'Water_Pump_TakTaz', 'machine_SPORT', 'abolfazl_prop', 'kolahkasket.ir', 'carkhavaran', 'sajadhafizi', 'VisionSport', 'lux_motor', 'eshghe_motor', 'Z4Car', 'mashingbaz', 'carmotoweap', 'mechanicali']
# ['khabargozariemehranmodiri', 'mohsenebrahimzadee', 'exoforever', 'Reyhaneparsaa', 'khoramaabaadi', 'mohamadaminkarimpor_soroush', 'ali_abdolmaleki.', 'mohhamadrezagolzar', 'taeyeon.a', 'Dr_pourmokhtar', 'dr_abbasi', 'Rezaee_ir', 'hasanereyvandi', 'EbrahimZadeh_Mohsen', 'azarijahromii']
# ['sadahravesh_animals', 'photoshop4224', 'harfbozorkan', 'Cyberdil', 'hoghogh_yar1', 'androidwindows1', 'diivar_ketab', 'mathacademyir', 'englishfansclub', 'hamyaremoalleman', 'informedparent', 'bonabdarolquran', 'النازپکوک', 'jalali', 'nooritekab']
# ['iran_tourism1', 'iranjaleb', 'Gardeshinews', 'biasafar', 'lookinns', 'charteriha', 'gashtoneh', 'favsbc51663vhxsbc', 'hiholiday24', 'marcopologroup', 'moraskhoon', 'vilarezerv', 'nehbandan', 'ami_gilan_jan']
# ['mod_zibaeiii', 'raz_zibayi', 'ideh.dokhtaraneh', 'zibaeerozz', 'dokhtarune.', 'qeisari_perfume', 'love_shopping', 'Fakhersara_khatam', 'storeroz1375', 'donyayenakhon', 'postvzibi', 'sormatik', 'pimpamchanel', 'Golshan_1340', 'teerajeh2']
# ['mahsolat_organnik', 'nini_food']
# ['sedaghatdarghalam', 'rahbarmane', 'yaraneemam', 'efaf313hejab', 'dgkalacom', 'bachehhaymadarpahloshekasteh', 'ROCK4ever4REAL', 'Outbears', 'kpop_channell', 'Nixonaccshop1', 'eshghefilm', 'alememojahed_malekhosseini', 'bachehhaymadarpahloshekasteh.ir', 'dokhtar_khass', 'return9_9', 'persepolisnewspage', 'nojo_andishkade', 'ROCK4ever4REAL', 'EyVey.', 'bachehhaymadarpahloshekasteh.ir', 'bachehhaymadarpahloshekasteh', 'Storyefake', 'mranir_meshkat.', 'Hejabfatemy', 'ngvnjnkhb', 'FOOTBALLBARTAR.TV3', 'kpop_channell', 'ashabolyamin2', 'turksel', 'shopingmehr', 'shahidrahvlayatchaghervand', 'Loove_city', 'Tah_khear', 'Zekr_allah', 'Souz_delan', 'andisheh_eshgh_', 'Gvarzeshi3New', 'sepahaneesfahann', 'janjahan.ir', 'mzmran', 'qmmran', 'qzmran', 'sbmran']
# ['Nixonaccshop1', 'hndgamer', 'bazibaz.ir', 'lego__legacy', 'ANDROIDxGAMES', 'lego.city', 'gameplay008', 'progamer1', 'Gamersworldd', 'bazigameply', 'mainecraftiha', 'Area_Game', 'bazarmaikt', 'Minecraftabad', 'Mine_world', 'spotify_account']
# ['bargi_az_salamati', 'asraare_salamati', 'tebsonati24', 'shamimislamiclife', 'pishgiri.darman', 'tebb_ebnesina', 'mavshoma20', 'tebzanashouei', 'safiranesalamatetehran', 'Hakim_ravazadeh', 'mumspr', 'zendegichannel', 'zalo_d', 'salamatbashid11', 'Dr20shayan']
# ['kpop_channell', 'alememojahed_malekhosseini', 'dgkalacom', 'efaf313hejab', 'yaraneemam', 'Nixonaccshop1', 'sedaghatdarghalam', 'Outbears', 'eshghefilm', 'bachehhaymadarpahloshekasteh', 'ROCK4ever4REAL', 'bachehhaymadarpahloshekasteh.ir', 'rahbarmane', 'dokhtar_khass', 'return9_9', 'persepolisnewspage', 'nojo_andishkade', 'ROCK4ever4REAL', 'EyVey.', 'bachehhaymadarpahloshekasteh.ir', 'bachehhaymadarpahloshekasteh', 'Storyefake', 'mranir_meshkat.', 'Hejabfatemy', 'ngvnjnkhb', 'FOOTBALLBARTAR.TV3', 'kpop_channell', 'ashabolyamin2', 'turksel', 'shopingmehr', 'shahidrahvlayatchaghervand', 'Loove_city', 'Tah_khear', 'Zekr_allah', 'Souz_delan', 'andisheh_eshgh_', 'Gvarzeshi3New', 'sepahaneesfahann', 'janjahan.ir', 'mzmran', 'qmmran', 'qzmran', 'sbmran']
# ['ROCK4ever4REAL', 'ROCK4ever4REAL', 'music.fa1', 'mocige.ir', 'music.r.ir', 'Systemmusic.ir', 'music_persian_iraan', 'Mehrab.iha', 'music_persian_ir', '16blackpink', 'mooje_tarane', 'hip_hoplovew', 'eidsepherhashemidehkordy', 'pershian.music', 'Savarnm', 'ahang.bomb']
# ['tabiate_shomall', 'golgol98', 'listgolha', 'kohnavarditehran', 'Samosh', 'ehyae_kashte_mosmer']
# ['khabarname_iran', 'ukashmar', 'iranianukraine', 'mardom_press', 'Seday_roudbarjonoob', 'titre.khabar', 'SdayKerman', 'rssnews', 'iran_newz_nzame', 'fahmanews', 'zagrosyan1', 'policekish', 'basirat_fa', 'akhbar_foriia', 'Tabasya']
# ['Storyefake', 'tasvir_h', 'wallpaper_land000', 'profailhd', 'qwertyuioprt', 'stiker3', 'wallpaper.photo', 'Aksprofail_shik', 'ax.text', 'baniaks', 'linkedon_soroush', 'ghamar_graph', 'akse_porofil', 'background_hd_topp', 'ak3por']
# ['persepolisnewspage', 'FOOTBALLBARTAR.TV3', 'Gvarzeshi3New', 'sepahaneesfahann', 'wallpaper_guy', 'tanzvarzeahi', 'championsfootballi', 'linkfottbali', 'basketballi_ha_2020', 'taekwondokaram', 'Taekwondo', 'Amozesh_futball', 'fcprespolis', 'starperspolis2', 'scopedp2020']
# ['faza.zaman', 'agaybwahshatnak', 'ajib_jaleb', 'Facts_brooz', 'howzehpajohesh', 'inmostfriends', 'sansortarikh', 'nojumferdows_01', 'iran5555', 'elm_daneshh', 'mstss.ir', 'Danestani_2019', 'danesht', 'tarfandis', 'saaedu']
# ['m_computer', 'Shahaabco', 'etrobot', 'signal98', 'botlist', 'indexme', 'mja_graphic', 'ghaleb_karbari', 'modern_afrough', 'PsnSeller_Best', 'mofidcomputer', 'shomaraan', 'khabar_i.t', 'info_wordpress', 'Amoozeshandroid']
# ['starstudio.official', 'funbahal', 'sorosh_tvs', 'video_culob', 'ifilm_hendi', 'sabalanirib', 'Cat.kh', 'Fan.tv', 'cvbnma', 'inestegram_clip', 'iribevimgararim', 'alkawtharchannel', 'clup_janjaliha', 'mostanad_plus', 'cafedubsmash']
# ['ngvnjnkhb', 'tolouanor', 'linkd0oni', 'member._.store', 'moaydibutik2', 'Linkdonilory', 'Shahidgoli3', 'linkdon1', 'linkcell', 'kafkhab_irany', 'linkdoni_iran', 'linkdoni_lirani', 'makepowerpoint', 'ndco.ahwaz', 'tondar_tab2']
# ['Outbears', 'Sablino2', 'آینده سازان', 'Coin_Service', 'Olymptrade4', 'Pooyan__', 'chinestan', 'Bors7', 'carorg', 'akhbar24h', 'pooshakitak', 'BitKoin_ir', 'Laleh_store', 'samantilestonetbz', 'offerisfahan', 'mahsolatarzan']
# ['rahbarmane', 'alememojahed_malekhosseini', 'bachehhaymadarpahloshekasteh.ir', 'yaraneemam', 'bachehhaymadarpahloshekasteh', 'dokhtar_khass', 'return9_9', 'nojo_andishkade', 'bachehhaymadarpahloshekasteh.ir', 'bachehhaymadarpahloshekasteh', 'mranir_meshkat.', 'Hejabfatemy', 'ashabolyamin2', 'shahidrahvlayatchaghervand', 'Zekr_allah', 'janjahan.ir', 'mzmran', 'qmmran', 'qzmran', 'sbmran']
# ['khanoomekhune', 'parsmfars', 'ashpaze_nemone', 'nokat_ashpazi1', 'simayekhanevade1', 'ashpazs1', 'chichi_products', 'bkhane', 'bekhaneh', 'ashpaziyetorkiyei', 'ashpazichas', 'Kitkat_shop', 'mazehbaazi', 'IranianCookery', 'Sarashpazy']
# ['Loove_city', 'Souz_delan', 'andisheh_eshgh_', 'pejmeh', 'romanhd', 'Ciel_gris', 'porofayl.nab', 'aks.porofayl', 'romancelean', 'jdjcjj', 'Nabtarin_text', 'avaye_baran1', 'Arezouyeman', 'ashghbikaran', 'biografei']
# ['kpop_channell', 'eshghefilm', 'kpop_channell', 'turksel', 'filmir.', 'Korea_lovely', 'bazimoontv3', 'filmov_ir', 'multiland', 'danlod__film', 'film_house', 'eshghefilm', 'clupmasoumieh38823419', 'bacupirani', 'film.seryal.kharej', 'world_media_milad', 'film.seryal.iran.kharej']
# ['dgkalacom', 'shopingmehr', 'Hishopir', 'bazarche', 'ketabkaraj', 'DigiYabi', 'Cafezibaiiha', 'xKHORSHIDx', 'jump_sport10', 'lavazemkhanegisarvari', 'mahsolatebarkat', 'fereshtekochoolooo', 'Armanpoosh', 'kafshebot', 'harajes', 'kala.shop1']

# %%
channels
# Out:
# {'animalshelter': ['1596916751013b4945pczb', 0],
#  'bazar_dam': ['1575377649254966a1anej', 1],
#  'phoenix_ilove': [-1, 2],
#  'natgeo': [-1, 3],
#  'siadpaliz': [-1, 4],
#  'zalooparvar.fadak': ['1551120607755381a97tep', 5],
#  'teyur966': ['1590621116667ddf584hzb', 6],
#  'Just_Fish': [-1, 7],
#  'poultry96': [-1, 8],
#  'LarrySerra': ['15283157929319f2956bWW8o', 9],
#  'amozeshkadecanary': ['1528051425118c84dc9fZVnA', 10],
#  'national_geographik': ['1593799434348f590dxtml', 11],
#  'aquarium_fish': [-1, 12],
#  'akvaruom.farzad': ['1528211523255c954e37O1f7', 13],
#  'toyyyour': ['1574330658539cfc29if1p', 14],
#  'otaku.net': [-1, 15],
#  'behtarinanime': ['1596911068592d739co0f0', 16],
#  'animefun': ['1596901484092ab66eab9w', 17],
#  'hamidmixer': [-1, 18],
#  'koodakonline1': [-1, 19],
#  'cartoonstv1': [-1, 20],
#  'animation_kotah': [-1, 21],
#  'andeshezeba': [-1, 22],
#  'clip_irancartoon': [-1, 23],
#  'og_instagram': [-1, 24],
#  'clip_kodakane': [-1, 25],
#  'tom_and_jery': [-1, 26],
#  'clip_babsfangi': [-1, 27],
#  'clip_cartoon': [-1, 28],
#  'clip_doniayecartoon': [-1, 29],
#  'tarh.graph': [-1, 30],
#  'Tablofarsh.chehre.mandegar': [-1, 31],
#  'logowhiteblack': [-1, 32],
#  'avindordoneh': [-1, 33],
#  'fatjmazahrayas': [-1, 34],
#  'artist_painter': [-1, 35],
#  'Mr.geraphic': [-1, 36],
#  'namadarzan': [-1, 37],
#  'ms_logo.ir': [-1, 38],
#  'Angoshtar_khatam': [-1, 39],
#  'sobhanms': [-1, 40],
#  'parvanjf': [-1, 41],
#  'epoxsiii': [-1, 42],
#  'naziricalligraphy': [-1, 43],
#  'Kaghzqom': [-1, 44],
#  'kayerpipe': [-1, 45],
#  '3dmax_farsi': [-1, 46],
#  'cc.architect': [-1, 47],
#  'mojriha': [-1, 48],
#  'decokara': [-1, 49],
#  'urbanity': [-1, 50],
#  'MAXWORLD_IR': [-1, 51],
#  'decoraat': [-1, 52],
#  'ostadekargari': [-1, 53],
#  'WAcars': [-1, 54],
#  '1dande_ir': [-1, 55],
#  'Water_Pump_TakTaz': [-1, 56],
#  'machine_SPORT': [-1, 57],
#  'abolfazl_prop': [-1, 58],
#  'kolahkasket.ir': [-1, 59],
#  'carkhavaran': [-1, 60],
#  'sajadhafizi': [-1, 61],
#  'VisionSport': [-1, 62],
#  'lux_motor': [-1, 63],
#  'eshghe_motor': [-1, 64],
#  'Z4Car': [-1, 65],
#  'mashingbaz': [-1, 66],
#  'carmotoweap': [-1, 67],
#  'mechanicali': [-1, 68],
#  'khabargozariemehranmodiri': [-1, 69],
#  'mohsenebrahimzadee': [-1, 70],
#  'exoforever': [-1, 71],
#  'Reyhaneparsaa': [-1, 72],
#  'khoramaabaadi': [-1, 73],
#  'mohamadaminkarimpor_soroush': [-1, 74],
#  'ali_abdolmaleki.': [-1, 75],
#  'mohhamadrezagolzar': [-1, 76],
#  'taeyeon.a': [-1, 77],
#  'Dr_pourmokhtar': [-1, 78],
#  'dr_abbasi': [-1, 79],
#  'Rezaee_ir': [-1, 80],
#  'hasanereyvandi': [-1, 81],
#  'EbrahimZadeh_Mohsen': [-1, 82],
#  'azarijahromii': [-1, 83],
#  'sadahravesh_animals': [-1, 84],
#  'photoshop4224': [-1, 85],
#  'harfbozorkan': [-1, 86],
#  'Cyberdil': [-1, 87],
#  'hoghogh_yar1': [-1, 88],
#  'androidwindows1': [-1, 89],
#  'diivar_ketab': [-1, 90],
#  'mathacademyir': [-1, 91],
#  'englishfansclub': [-1, 92],
#  'hamyaremoalleman': [-1, 93],
#  'informedparent': [-1, 94],
#  'bonabdarolquran': [-1, 95],
#  'النازپکوک': [-1, 96],
#  'jalali': [-1, 97],
#  'nooritekab': [-1, 98],
#  'iran_tourism1': [-1, 99],
#  'iranjaleb': [-1, 100],
#  'Gardeshinews': [-1, 101],
#  'biasafar': [-1, 102],
#  'lookinns': [-1, 103],
#  'charteriha': [-1, 104],
#  'gashtoneh': [-1, 105],
#  'favsbc51663vhxsbc': [-1, 106],
#  'hiholiday24': [-1, 107],
#  'marcopologroup': [-1, 108],
#  'moraskhoon': [-1, 109],
#  'vilarezerv': [-1, 110],
#  'nehbandan': [-1, 111],
#  'ami_gilan_jan': [-1, 112],
#  'mod_zibaeiii': [-1, 113],
#  'raz_zibayi': [-1, 114],
#  'ideh.dokhtaraneh': [-1, 115],
#  'zibaeerozz': [-1, 116],
#  'dokhtarune.': [-1, 117],
#  'qeisari_perfume': [-1, 118],
#  'love_shopping': [-1, 119],
#  'Fakhersara_khatam': [-1, 120],
#  'storeroz1375': [-1, 121],
#  'donyayenakhon': [-1, 122],
#  'postvzibi': [-1, 123],
#  'sormatik': [-1, 124],
#  'pimpamchanel': [-1, 125],
#  'Golshan_1340': [-1, 126],
#  'teerajeh2': [-1, 127],
#  'mahsolat_organnik': [-1, 128],
#  'nini_food': [-1, 129],
#  'sedaghatdarghalam': [-1, 210],
#  'rahbarmane': [-1, 390],
#  'yaraneemam': [-1, 393],
#  'efaf313hejab': [-1, 207],
#  'dgkalacom': [-1, 457],
#  'bachehhaymadarpahloshekasteh': [-1, 399],
#  'ROCK4ever4REAL': [-1, 248],
#  'Outbears': [-1, 374],
#  'kpop_channell': [-1, 442],
#  'Nixonaccshop1': [-1, 209],
#  'eshghefilm': [-1, 451],
#  'alememojahed_malekhosseini': [-1, 391],
#  'bachehhaymadarpahloshekasteh.ir': [-1, 398],
#  'dokhtar_khass': [-1, 395],
#  'return9_9': [-1, 396],
#  'persepolisnewspage': [-1, 299],
#  'nojo_andishkade': [-1, 397],
#  'EyVey.': [-1, 222],
#  'Storyefake': [-1, 284],
#  'mranir_meshkat.': [-1, 400],
#  'Hejabfatemy': [-1, 401],
#  'ngvnjnkhb': [-1, 359],
#  'FOOTBALLBARTAR.TV3': [-1, 300],
#  'ashabolyamin2': [-1, 402],
#  'turksel': [-1, 443],
#  'shopingmehr': [-1, 458],
#  'shahidrahvlayatchaghervand': [-1, 403],
#  'Loove_city': [-1, 425],
#  'Tah_khear': [-1, 236],
#  'Zekr_allah': [-1, 404],
#  'Souz_delan': [-1, 426],
#  'andisheh_eshgh_': [-1, 427],
#  'Gvarzeshi3New': [-1, 301],
#  'sepahaneesfahann': [-1, 302],
#  'janjahan.ir': [-1, 405],
#  'mzmran': [-1, 406],
#  'qmmran': [-1, 407],
#  'qzmran': [-1, 408],
#  'sbmran': [-1, 409],
#  'hndgamer': [-1, 174],
#  'bazibaz.ir': [-1, 175],
#  'lego__legacy': [-1, 176],
#  'ANDROIDxGAMES': [-1, 177],
#  'lego.city': [-1, 178],
#  'gameplay008': [-1, 179],
#  'progamer1': [-1, 180],
#  'Gamersworldd': [-1, 181],
#  'bazigameply': [-1, 182],
#  'mainecraftiha': [-1, 183],
#  'Area_Game': [-1, 184],
#  'bazarmaikt': [-1, 185],
#  'Minecraftabad': [-1, 186],
#  'Mine_world': [-1, 187],
#  'spotify_account': [-1, 188],
#  'bargi_az_salamati': [-1, 189],
#  'asraare_salamati': [-1, 190],
#  'tebsonati24': [-1, 191],
#  'shamimislamiclife': [-1, 192],
#  'pishgiri.darman': [-1, 193],
#  'tebb_ebnesina': [-1, 194],
#  'mavshoma20': [-1, 195],
#  'tebzanashouei': [-1, 196],
#  'safiranesalamatetehran': [-1, 197],
#  'Hakim_ravazadeh': [-1, 198],
#  'mumspr': [-1, 199],
#  'zendegichannel': [-1, 200],
#  'zalo_d': [-1, 201],
#  'salamatbashid11': [-1, 202],
#  'Dr20shayan': [-1, 203],
#  'music.fa1': [-1, 249],
#  'mocige.ir': [-1, 250],
#  'music.r.ir': [-1, 251],
#  'Systemmusic.ir': [-1, 252],
#  'music_persian_iraan': [-1, 253],
#  'Mehrab.iha': [-1, 254],
#  'music_persian_ir': [-1, 255],
#  '16blackpink': [-1, 256],
#  'mooje_tarane': [-1, 257],
#  'hip_hoplovew': [-1, 258],
#  'eidsepherhashemidehkordy': [-1, 259],
#  'pershian.music': [-1, 260],
#  'Savarnm': [-1, 261],
#  'ahang.bomb': [-1, 262],
#  'tabiate_shomall': [-1, 263],
#  'golgol98': [-1, 264],
#  'listgolha': [-1, 265],
#  'kohnavarditehran': [-1, 266],
#  'Samosh': [-1, 267],
#  'ehyae_kashte_mosmer': [-1, 268],
#  'khabarname_iran': [-1, 269],
#  'ukashmar': [-1, 270],
#  'iranianukraine': [-1, 271],
#  'mardom_press': [-1, 272],
#  'Seday_roudbarjonoob': [-1, 273],
#  'titre.khabar': [-1, 274],
#  'SdayKerman': [-1, 275],
#  'rssnews': [-1, 276],
#  'iran_newz_nzame': [-1, 277],
#  'fahmanews': [-1, 278],
#  'zagrosyan1': [-1, 279],
#  'policekish': [-1, 280],
#  'basirat_fa': [-1, 281],
#  'akhbar_foriia': [-1, 282],
#  'Tabasya': [-1, 283],
#  'tasvir_h': [-1, 285],
#  'wallpaper_land000': [-1, 286],
#  'profailhd': [-1, 287],
#  'qwertyuioprt': [-1, 288],
#  'stiker3': [-1, 289],
#  'wallpaper.photo': [-1, 290],
#  'Aksprofail_shik': [-1, 291],
#  'ax.text': [-1, 292],
#  'baniaks': [-1, 293],
#  'linkedon_soroush': [-1, 294],
#  'ghamar_graph': [-1, 295],
#  'akse_porofil': [-1, 296],
#  'background_hd_topp': [-1, 297],
#  'ak3por': [-1, 298],
#  'wallpaper_guy': [-1, 303],
#  'tanzvarzeahi': [-1, 304],
#  'championsfootballi': [-1, 305],
#  'linkfottbali': [-1, 306],
#  'basketballi_ha_2020': [-1, 307],
#  'taekwondokaram': [-1, 308],
#  'Taekwondo': [-1, 309],
#  'Amozesh_futball': [-1, 310],
#  'fcprespolis': [-1, 311],
#  'starperspolis2': [-1, 312],
#  'scopedp2020': [-1, 313],
#  'faza.zaman': [-1, 314],
#  'agaybwahshatnak': [-1, 315],
#  'ajib_jaleb': [-1, 316],
#  'Facts_brooz': [-1, 317],
#  'howzehpajohesh': [-1, 318],
#  'inmostfriends': [-1, 319],
#  'sansortarikh': [-1, 320],
#  'nojumferdows_01': [-1, 321],
#  'iran5555': [-1, 322],
#  'elm_daneshh': [-1, 323],
#  'mstss.ir': [-1, 324],
#  'Danestani_2019': [-1, 325],
#  'danesht': [-1, 326],
#  'tarfandis': [-1, 327],
#  'saaedu': [-1, 328],
#  'm_computer': [-1, 329],
#  'Shahaabco': [-1, 330],
#  'etrobot': [-1, 331],
#  'signal98': [-1, 332],
#  'botlist': [-1, 333],
#  'indexme': [-1, 334],
#  'mja_graphic': [-1, 335],
#  'ghaleb_karbari': [-1, 336],
#  'modern_afrough': [-1, 337],
#  'PsnSeller_Best': [-1, 338],
#  'mofidcomputer': [-1, 339],
#  'shomaraan': [-1, 340],
#  'khabar_i.t': [-1, 341],
#  'info_wordpress': [-1, 342],
#  'Amoozeshandroid': [-1, 343],
#  'starstudio.official': [-1, 344],
#  'funbahal': [-1, 345],
#  'sorosh_tvs': [-1, 346],
#  'video_culob': [-1, 347],
#  'ifilm_hendi': [-1, 348],
#  'sabalanirib': [-1, 349],
#  'Cat.kh': [-1, 350],
#  'Fan.tv': [-1, 351],
#  'cvbnma': [-1, 352],
#  'inestegram_clip': [-1, 353],
#  'iribevimgararim': [-1, 354],
#  'alkawtharchannel': [-1, 355],
#  'clup_janjaliha': [-1, 356],
#  'mostanad_plus': [-1, 357],
#  'cafedubsmash': [-1, 358],
#  'tolouanor': [-1, 360],
#  'linkd0oni': [-1, 361],
#  'member._.store': [-1, 362],
#  'moaydibutik2': [-1, 363],
#  'Linkdonilory': [-1, 364],
#  'Shahidgoli3': [-1, 365],
#  'linkdon1': [-1, 366],
#  'linkcell': [-1, 367],
#  'kafkhab_irany': [-1, 368],
#  'linkdoni_iran': [-1, 369],
#  'linkdoni_lirani': [-1, 370],
#  'makepowerpoint': [-1, 371],
#  'ndco.ahwaz': [-1, 372],
#  'tondar_tab2': [-1, 373],
#  'Sablino2': [-1, 375],
#  'آینده سازان': [-1, 376],
#  'Coin_Service': [-1, 377],
#  'Olymptrade4': [-1, 378],
#  'Pooyan__': [-1, 379],
#  'chinestan': [-1, 380],
#  'Bors7': [-1, 381],
#  'carorg': [-1, 382],
#  'akhbar24h': [-1, 383],
#  'pooshakitak': [-1, 384],
#  'BitKoin_ir': [-1, 385],
#  'Laleh_store': [-1, 386],
#  'samantilestonetbz': [-1, 387],
#  'offerisfahan': [-1, 388],
#  'mahsolatarzan': [-1, 389],
#  'khanoomekhune': [-1, 410],
#  'parsmfars': [-1, 411],
#  'ashpaze_nemone': [-1, 412],
#  'nokat_ashpazi1': [-1, 413],
#  'simayekhanevade1': [-1, 414],
#  'ashpazs1': [-1, 415],
#  'chichi_products': [-1, 416],
#  'bkhane': [-1, 417],
#  'bekhaneh': [-1, 418],
#  'ashpaziyetorkiyei': [-1, 419],
#  'ashpazichas': [-1, 420],
#  'Kitkat_shop': [-1, 421],
#  'mazehbaazi': [-1, 422],
#  'IranianCookery': [-1, 423],
#  'Sarashpazy': [-1, 424],
#  'pejmeh': [-1, 428],
#  'romanhd': [-1, 429],
#  'Ciel_gris': [-1, 430],
#  'porofayl.nab': [-1, 431],
#  'aks.porofayl': [-1, 432],
#  'romancelean': [-1, 433],
#  'jdjcjj': [-1, 434],
#  'Nabtarin_text': [-1, 435],
#  'avaye_baran1': [-1, 436],
#  'Arezouyeman': [-1, 437],
#  'ashghbikaran': [-1, 438],
#  'biografei': [-1, 439],
#  'filmir.': [-1, 444],
#  'Korea_lovely': [-1, 445],
#  'bazimoontv3': [-1, 446],
#  'filmov_ir': [-1, 447],
#  'multiland': [-1, 448],
#  'danlod__film': [-1, 449],
#  'film_house': [-1, 450],
#  'clupmasoumieh38823419': [-1, 452],
#  'bacupirani': [-1, 453],
#  'film.seryal.kharej': [-1, 454],
#  'world_media_milad': [-1, 455],
#  'film.seryal.iran.kharej': [-1, 456],
#  'Hishopir': [-1, 459],
#  'bazarche': [-1, 460],
#  'ketabkaraj': [-1, 461],
#  'DigiYabi': [-1, 462],
#  'Cafezibaiiha': [-1, 463],
#  'xKHORSHIDx': [-1, 464],
#  'jump_sport10': [-1, 465],
#  'lavazemkhanegisarvari': [-1, 466],
#  'mahsolatebarkat': [-1, 467],
#  'fereshtekochoolooo': [-1, 468],
#  'Armanpoosh': [-1, 469],
#  'kafshebot': [-1, 470],
#  'harajes': [-1, 471],
#  'kala.shop1': [-1, 472]}

# %%
# !python -m pip install pykafka
from pykafka import KafkaClient
# from kafka import KafkaProducer
# producer = KafkaProducer(bootstrap_servers='localhost:9092')
client = KafkaClient(hosts="127.0.0.1:9092")
topic = client.topics["test4"]

import hashlib
import requests
import json
from time import sleep
import sseclient
def get_channel_data(channel_name, size, last_message_id):
    endpoint = 'channel/archive'
    a = "95d58639"
    b = "24c0"
    c = "4b72"
    d = "80a5"
    f = "e124f41d7af9"
    api_secret = "-".join([a,b,c,d,f])
    api_resource = 'channel/archive'
    clinet_id = '7743461522282941752'
    format = 'json'
    api_version = 'v1'
    if last_message_id != -1:
        message = f'{{"channel_id":"{channel_name}", "limit": {size}, "message_id": "{last_message_id}"}}'
    else:
        message = f'{{"channel_id":"{channel_name}", "limit": {size}}}'
    digest = hashlib.md5((api_secret+api_version+format+clinet_id+api_resource+message).encode('utf-8')).hexdigest()
    url = f"https://what.sapp.ir/srvcs-app/v1/json/7743461522282941752/{digest}/channel/archive"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
        'keep_alive':'False'
    }
    

    rq = requests.post(url, data = message.encode("utf-8"), headers=headers)
    res = json.loads(rq.text)
    return res
import re

main_words = ['بورس','اقتصاد','تحریم','دولت','دلار','طلا','کرونا','شاخص بورس','تورم','دانشگاه','سقوط','رشد']
# channels = {'iribnews':[-1,0]}
while(True):
    for channel,msgid in channels.items():
        out = get_channel_data(channel,2,-1)
        if type(out) == list:
            print('Oops')
            continue
        #print(out)
        if(out['messages'][0]['message_id'] != msgid[0]):
            channels[channel][0] = out['messages'][0]['message_id']
            out['messages'][0]['index'] = msgid[1]
            out['messages'][0]['metadata'] = [tag.strip("#") for tag in out['messages'][0]['text'].split() if tag.startswith("#")] + out['messages'][0]['frequency_word'] + [word for word in main_words if word in out['messages'][0]['text']]
            out['messages'][0]['hashtags'] = [tag.strip("#") for tag in out['messages'][0]['text'].split() if tag.startswith("#")]
            out['messages'][0]['links'] = re.findall(r'(https?://[^\s]+)', out['messages'][0]['text'])
            if out['messages'][0]['file']['extention']=='jpg':
                out['messages'][0]['images'] = [out['messages'][0]['file']['url']]
            else :
                out['messages'][0]['images'] = []
            # print(out['messages'][0])
            # print(' ')
            #publish_message(kafka_producer, 'test', 'raw', out['messages'][0])
            with topic.get_sync_producer() as producer:
                producer.produce(bytes(str(out['messages'][0]), encoding='utf-8'))
    sleep(180)
# Out:
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# Oops
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-531d768b91ad> in <module>
#      49             continue
#      50         #print(out)
# ---> 51         if(out['messages'][0]['message_id'] != msgid[0]):
#      52             channels[channel][0] = out['messages'][0]['message_id']
#      53             out['messages'][0]['index'] = msgid[1]
#
# KeyError: 'messages'
